# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("b2b_directory_data.csv")

# %%
df
# Out:
#                      Company Name                            Website URL  \
# 0                   Geeks On Site                                    NaN
# 1     AAA All Voice And Data Inc.                                    NaN
# 2               My Computer Works                                    NaN
# 3                   Geeks On Site                                    NaN
# 4               My Computer Works                                    NaN
# ..                            ...                                    ...
# 87                      Cybercity              https://www.cybercity.nyc
# 88   Global Data Publications Inc  https://www.globaldata.com/contact-us
# 89  New York Computer Help - SOHO    https://www.newyorkcomputerhelp.com
# 90                  Promethean IT                                    NaN
# 91             Tech Support 4 NYC         http://www.techsupport4nyc.com
#
#     Contact Number                              Location/Address  \
# 0              NaN                                           NaN
# 1              NaN                                           NaN
# 2   (800) 262-2219                                           NaN
# 3   (800) 531-2349                                           NaN
# 4   (877) 201-0623                                           NaN
# ..             ...                                           ...
# 87  (212) 633-0649               224 W 30th StNew York, NY 10001
# 88  (646) 395-5460           441 Lexington AveNew York, NY 10017
# 89  (212) 599-0339         110 Greene St Fl 11New York, NY 10012
# 90  (212) 226-6686              65 Bleecker StNew York, NY 10012
# 91  (877) 467-4989  900 Avenue Of The AmericasNew York, NY 10011
#
#    Industry/Category                                Company Description  \
# 0        IT Services                                                NaN
# 1        IT Services                                                NaN
# 2        IT Services  Nice support from their office thanks for ever...
# 3        IT Services  From Business: If you are in a crunch, Geeks o...
# 4        IT Services  From Business: Our professional and polite U.S...
# ..               ...                                                ...
# 87       IT Services  Avoid them.  Our server crashed while we were ...
# 88       IT Services  I found this company on Craigslist advertising...
# 89       IT Services  From Business: Founded in 2000, our computer s...
# 90       IT Services  From Business: The ancient myth of Prometheus ...
# 91       IT Services  From Business: Computer Consulting firm servic...
#
#     Email Address
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 87            NaN
# 88            NaN
# 89            NaN
# 90            NaN
# 91            NaN
#
# [92 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Company Name', 'Website URL', 'Contact Number', 'Location/Address',
#        'Industry/Category', 'Company Description', 'Email Address'],
#       dtype='object')

# %%
df.head()
# Out:
#                   Company Name Website URL  Contact Number Location/Address  \
# 0                Geeks On Site         NaN             NaN              NaN
# 1  AAA All Voice And Data Inc.         NaN             NaN              NaN
# 2            My Computer Works         NaN  (800) 262-2219              NaN
# 3                Geeks On Site         NaN  (800) 531-2349              NaN
# 4            My Computer Works         NaN  (877) 201-0623              NaN
#
#   Industry/Category                                Company Description  \
# 0       IT Services                                                NaN
# 1       IT Services                                                NaN
# 2       IT Services  Nice support from their office thanks for ever...
# 3       IT Services  From Business: If you are in a crunch, Geeks o...
# 4       IT Services  From Business: Our professional and polite U.S...
#
#    Email Address
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company Name         92 non-null     object
#  1   Website URL          55 non-null     object
#  2   Contact Number       90 non-null     object
#  3   Location/Address     86 non-null     object
#  4   Industry/Category    92 non-null     object
#  5   Company Description  62 non-null     object
#  6   Email Address        0 non-null      float64
# dtypes: float64(1), object(6)
# memory usage: 5.2+ KB

# %%
df.shape
# Out:
# (92, 7)

# %%
df.isna().sum()
# Out:
# Company Name            0
# Website URL            37
# Contact Number          2
# Location/Address        6
# Industry/Category       0
# Company Description    30
# Email Address          92
# dtype: int64

# %%
# In email address all vaues are empty. so we are delete this columns

df=df.drop(columns=['Email Address'])

# %%
df
# Out:
#                      Company Name                            Website URL  \
# 0                   Geeks On Site                                    NaN
# 1     AAA All Voice And Data Inc.                                    NaN
# 2               My Computer Works                                    NaN
# 3                   Geeks On Site                                    NaN
# 4               My Computer Works                                    NaN
# ..                            ...                                    ...
# 87                      Cybercity              https://www.cybercity.nyc
# 88   Global Data Publications Inc  https://www.globaldata.com/contact-us
# 89  New York Computer Help - SOHO    https://www.newyorkcomputerhelp.com
# 90                  Promethean IT                                    NaN
# 91             Tech Support 4 NYC         http://www.techsupport4nyc.com
#
#     Contact Number                              Location/Address  \
# 0              NaN                                           NaN
# 1              NaN                                           NaN
# 2   (800) 262-2219                                           NaN
# 3   (800) 531-2349                                           NaN
# 4   (877) 201-0623                                           NaN
# ..             ...                                           ...
# 87  (212) 633-0649               224 W 30th StNew York, NY 10001
# 88  (646) 395-5460           441 Lexington AveNew York, NY 10017
# 89  (212) 599-0339         110 Greene St Fl 11New York, NY 10012
# 90  (212) 226-6686              65 Bleecker StNew York, NY 10012
# 91  (877) 467-4989  900 Avenue Of The AmericasNew York, NY 10011
#
#    Industry/Category                                Company Description
# 0        IT Services                                                NaN
# 1        IT Services                                                NaN
# 2        IT Services  Nice support from their office thanks for ever...
# 3        IT Services  From Business: If you are in a crunch, Geeks o...
# 4        IT Services  From Business: Our professional and polite U.S...
# ..               ...                                                ...
# 87       IT Services  Avoid them.  Our server crashed while we were ...
# 88       IT Services  I found this company on Craigslist advertising...
# 89       IT Services  From Business: Founded in 2000, our computer s...
# 90       IT Services  From Business: The ancient myth of Prometheus ...
# 91       IT Services  From Business: Computer Consulting firm servic...
#
# [92 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Company Name            0
# Website URL            37
# Contact Number          2
# Location/Address        6
# Industry/Category       0
# Company Description    30
# dtype: int64

# %%
# now handle missing values 
#Drop rows with missing 'Contact Number' (assuming it's essential)

df = df.dropna(subset=['Contact Number'])

# %%
df.isna().sum()
# Out:
# Company Name            0
# Website URL            35
# Contact Number          0
# Location/Address        4
# Industry/Category       0
# Company Description    28
# dtype: int64

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
 # Fill missing values in 'Website URL' and 'Location/Address' with placeholders
df['Website URL'].fillna('Not Available', inplace=True)
df['Location/Address'].fillna('Not Provided', inplace=True)

# %%
df.isna().sum()
# Out:
# Company Name            0
# Website URL             0
# Contact Number          0
# Location/Address        0
# Industry/Category       0
# Company Description    28
# dtype: int64

# %%
#fill missing values in 'Company Description' with a placeholder

df['Company Description'].fillna('Description Not Available', inplace=True)

# %%
df.isna().sum()
# Out:
# Company Name           0
# Website URL            0
# Contact Number         0
# Location/Address       0
# Industry/Category      0
# Company Description    0
# dtype: int64

# %%
df
# Out:
#                      Company Name  \
# 2               My Computer Works
# 3                   Geeks On Site
# 4               My Computer Works
# 5                   Geeks on Site
# 6     AAA All Voice And Data Inc.
# ..                            ...
# 87                      Cybercity
# 88   Global Data Publications Inc
# 89  New York Computer Help - SOHO
# 90                  Promethean IT
# 91             Tech Support 4 NYC
#
#                                           Website URL  Contact Number  \
# 2                                       Not Available  (800) 262-2219
# 3                                       Not Available  (800) 531-2349
# 4                                       Not Available  (877) 201-0623
# 5                                       Not Available  (877) 223-4607
# 6   https://api.superpages.com/xml/search?SRC=ypin...  (646) 921-7849
# ..                                                ...             ...
# 87                          https://www.cybercity.nyc  (212) 633-0649
# 88              https://www.globaldata.com/contact-us  (646) 395-5460
# 89                https://www.newyorkcomputerhelp.com  (212) 599-0339
# 90                                      Not Available  (212) 226-6686
# 91                     http://www.techsupport4nyc.com  (877) 467-4989
#
#                                 Location/Address Industry/Category  \
# 2                                   Not Provided       IT Services
# 3                                   Not Provided       IT Services
# 4                                   Not Provided       IT Services
# 5                                   Not Provided       IT Services
# 6          303 Avenue P Apt F7Brooklyn, NY 11204       IT Services
# ..                                           ...               ...
# 87               224 W 30th StNew York, NY 10001       IT Services
# 88           441 Lexington AveNew York, NY 10017       IT Services
# 89         110 Greene St Fl 11New York, NY 10012       IT Services
# 90              65 Bleecker StNew York, NY 10012       IT Services
# 91  900 Avenue Of The AmericasNew York, NY 10011       IT Services
#
#                                   Company Description
# 2   Nice support from their office thanks for ever...
# 3   From Business: If you are in a crunch, Geeks o...
# 4   From Business: Our professional and polite U.S...
# 5   From Business: With over 20 years of experienc...
# 6   Guys from AAA did great installation for us.  ...
# ..                                                ...
# 87  Avoid them.  Our server crashed while we were ...
# 88  I found this company on Craigslist advertising...
# 89  From Business: Founded in 2000, our computer s...
# 90  From Business: The ancient myth of Prometheus ...
# 91  From Business: Computer Consulting firm servic...
#
# [90 rows x 6 columns]

# %%
# Out:
#                      Company Name  \
# 2               My Computer Works
# 3                   Geeks On Site
# 4               My Computer Works
# 5                   Geeks on Site
# 6     AAA All Voice And Data Inc.
# ..                            ...
# 87                      Cybercity
# 88   Global Data Publications Inc
# 89  New York Computer Help - SOHO
# 90                  Promethean IT
# 91             Tech Support 4 NYC
#
#                                           Website URL  Contact Number  \
# 2                                       Not Available  (800) 262-2219
# 3                                       Not Available  (800) 531-2349
# 4                                       Not Available  (877) 201-0623
# 5                                       Not Available  (877) 223-4607
# 6   https://api.superpages.com/xml/search?SRC=ypin...  (646) 921-7849
# ..                                                ...             ...
# 87                          https://www.cybercity.nyc  (212) 633-0649
# 88              https://www.globaldata.com/contact-us  (646) 395-5460
# 89                https://www.newyorkcomputerhelp.com  (212) 599-0339
# 90                                      Not Available  (212) 226-6686
# 91                     http://www.techsupport4nyc.com  (877) 467-4989
#
#                                 Location/Address Industry/Category  \
# 2                                   Not Provided       IT Services
# 3                                   Not Provided       IT Services
# 4                                   Not Provided       IT Services
# 5                                   Not Provided       IT Services
# 6          303 Avenue P Apt F7Brooklyn, NY 11204       IT Services
# ..                                           ...               ...
# 87               224 W 30th StNew York, NY 10001       IT Services
# 88           441 Lexington AveNew York, NY 10017       IT Services
# 89         110 Greene St Fl 11New York, NY 10012       IT Services
# 90              65 Bleecker StNew York, NY 10012       IT Services
# 91  900 Avenue Of The AmericasNew York, NY 10011       IT Services
#
#                                   Company Description
# 2   Nice support from their office thanks for ever...
# 3   From Business: If you are in a crunch, Geeks o...
# 4   From Business: Our professional and polite U.S...
# 5   From Business: With over 20 years of experienc...
# 6   Guys from AAA did great installation for us.  ...
# ..                                                ...
# 87  Avoid them.  Our server crashed while we were ...
# 88  I found this company on Craigslist advertising...
# 89  From Business: Founded in 2000, our computer s...
# 90  From Business: The ancient myth of Prometheus ...
# 91  From Business: Computer Consulting firm servic...
#
# [90 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
